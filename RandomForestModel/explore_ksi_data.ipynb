# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv("ksi_collisions.csv")
severe_df = df[df["SEVERE_COLLISION"] == 1]

# %%
df.shape
# Out:
# (18957, 19)

# %%
severe_df.shape
# Out:
# (8996, 19)

# %%
df.sample(1)
# Out:
#             DATE  STREET1        STREET2        DISTRICT   LATITUDE  \
# 2281  2007-07-22  JANE ST  SAN MARINOWAY  Etobicoke York  43.744145
#
#       LONGITUDE VISIBILITY     LIGHT ROAD_CONDITION           ACCLASS  \
# 2281  -79.51439      Clear  Daylight            Dry  Non-Fatal Injury
#
#        INJURY  FATAL_NO HOOD_158       NEIGHBOURHOOD_158     DOW  HOUR  YEAR  \
# 2281  Minimal       0.0       25  Glenfield-Jane Heights  Sunday    13  2007
#
#       SEVERE_COLLISION TIME_OF_DAY
# 2281                 0   Afternoon

# %%
sns.countplot(x="YEAR", data=df)
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
sns.countplot(x="HOUR", data=df)
# Out:
# <Axes: xlabel='HOUR', ylabel='count'>

# %%
sns.countplot(x="HOUR", data=severe_df)
# Out:
# <Axes: xlabel='HOUR', ylabel='count'>

# %%
sns.countplot(x="TIME_OF_DAY", data=df)
# Out:
# <Axes: xlabel='TIME_OF_DAY', ylabel='count'>

# %%
sns.countplot(x="LIGHT", data=df)
# Out:
# <Axes: xlabel='LIGHT', ylabel='count'>

# %%
sns.countplot(x="VISIBILITY", data=df)
# Out:
# <Axes: xlabel='VISIBILITY', ylabel='count'>

# %%
sns.countplot(x="ROAD_CONDITION", data=df)
# Out:
# <Axes: xlabel='ROAD_CONDITION', ylabel='count'>
